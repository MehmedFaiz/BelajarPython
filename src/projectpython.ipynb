# %%
import pandas as pd

data = {
    "jam_belajar": [1, 2, 3, 4, 5],
    "nilai": [50, 60, 70, 80, 90]
}

df = pd.DataFrame(data)
df
# Out:
#    jam_belajar  nilai
# 0            1     50
# 1            2     60
# 2            3     70
# 3            4     80
# 4            5     90
